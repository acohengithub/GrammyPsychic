# %% [markdown]
# Alex Cohen <br>
# BrainStation Capstone Project

# %% [markdown]
# Goal: Can we use Spotify data and Machine Learning to predict songs that will win Grammys based on previous winners

# %% [markdown]
# This workbook will showcase the process for collecting audio data from Spotify playlists conatining Record of the Year winners, nominees as well as a variety of other songs from the past 60 years

# %%
# Standard imports
import numpy as np
import pandas as pd

# For web scraping
import requests
from bs4 import BeautifulSoup

# For performing regex operations
import re

# For adding delays so that we don't spam requests
import time

# %% [markdown]
# ## Installing spotipy to access Spotify API

# %%
pip install spotify
# Out:
# Requirement already satisfied: spotify in /Users/alexcohen/opt/anaconda3/lib/python3.8/site-packages (0.10.2)
# Requirement already satisfied: backoff<2.0.0,>=1.10.0 in /Users/alexcohen/opt/anaconda3/lib/python3.8/site-packages (from spotify) (1.10.0)
# Requirement already satisfied: aiohttp<4.0,>=3.6 in /Users/alexcohen/opt/anaconda3/lib/python3.8/site-packages (from spotify) (3.6.2)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /Users/alexcohen/opt/anaconda3/lib/python3.8/site-packages (from aiohttp<4.0,>=3.6->spotify) (3.0.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/alexcohen/opt/anaconda3/lib/python3.8/site-packages (from aiohttp<4.0,>=3.6->spotify) (1.5.1)
# Requirement already satisfied: multidict<5.0,>=4.5 in /Users/alexcohen/opt/anaconda3/lib/python3.8/site-packages (from aiohttp<4.0,>=3.6->spotify) (4.7.6)
# Requirement already satisfied: chardet<4.0,>=2.0 in /Users/alexcohen/opt/anaconda3/lib/python3.8/site-packages (from aiohttp<4.0,>=3.6->spotify) (3.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /Users/alexcohen/opt/anaconda3/lib/python3.8/site-packages (from aiohttp<4.0,>=3.6->spotify) (19.3.0)
# Requirement already satisfied: idna>=2.0 in /Users/alexcohen/opt/anaconda3/lib/python3.8/site-packages (from yarl<2.0,>=1.0->aiohttp<4.0,>=3.6->spotify) (2.10)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# IMPORTING SPOTIFY API - SPOTIPY

# %%
import spotipy

from spotipy.oauth2 import SpotifyClientCredentials

cid = '3005424aca5d4ca0bc006510258039ee'
secret = '0b2ff02fc80644b9a33c6dd900a3ea7d'

client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager
=
client_credentials_manager)

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /Users/alexcohen/opt/anaconda3/lib/python3.8/site-packages (2.24.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/alexcohen/opt/anaconda3/lib/python3.8/site-packages (from requests) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/alexcohen/opt/anaconda3/lib/python3.8/site-packages (from requests) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /Users/alexcohen/opt/anaconda3/lib/python3.8/site-packages (from requests) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/alexcohen/opt/anaconda3/lib/python3.8/site-packages (from requests) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import ast
from typing import List
from os import listdir
def get_streamings(path: str = 'MyData') -> List[dict]:
    
    files = ['MyData/' + x for x in listdir(path)
             if x.split('.')[0][:-1] == 'StreamingHistory']
    
    all_streamings = []
    
    for file in files: 
        with open(file, 'r', encoding='UTF-8') as f:
            new_streamings = ast.literal_eval(f.read())
            all_streamings += [streaming for streaming 
                               in new_streamings]
    return all_streamings

# %%
all_streamings
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-1e70c2059599> in <module>
# ----> 1 all_streamings
#
# NameError: name 'all_streamings' is not defined

# %%
import spotipy.util as util

username = '12138672436'
client_id ='3005424aca5d4ca0bc006510258039ee'
client_secret = '0b2ff02fc80644b9a33c6dd900a3ea7d'
redirect_uri = 'http://localhost:7777/callback'
scope = 'user-read-recently-played'

token = util.prompt_for_user_token(username=username, 
                                   scope=scope, 
                                   client_id=client_id,   
                                   client_secret=client_secret,     
                                   redirect_uri=redirect_uri)
# Out:
# Couldn't read cache at: .cache-12138672436
# Couldn't read cache at: .cache-12138672436

# %%
print(token)
# Out:
# BQCU98QTkvTla1dkpjXzwy-53tR6Q8pL3QRpYBWZXtBkkPdKXtjNgYWIX2I-vwfGTRnd3rvbL7_MsKoPbTxxkiH9dYAmRtzGq_v1FGviE3ADmKRCT5IeNkwsgc8r1zNPCsDVpZKX_FA2-ijxIxDs1mPN

# %% [markdown]
# ## Writing code to pull out track IDs from Spotify API

# %%
import requests

def get_id(track_name: str, token: str):
    headers = {'Accept': 'application/json', 'Content-Type': 'application/json', 'Authorization': f'Bearer ' + token}
    
    params = [('q', track_name), ('type', 'track')]
    
    try:
        response = requests.get('https://api.spotify.com/v1/search', 
                    headers = headers, params = params, timeout = 5)
        json = response.json()
        first_result = json['tracks']['items'][0]
        track_id = first_result['id']
        
        return track_id
    except:
        return None

# %%
dmcb_id = get_id('Dreams Money Can Buy', token)
print(dmcb_id)
# Out:
# 1qyFlfPREPbRcS2BNszdYI

# %%
def get_features(track_id: str, token: str) -> dict:
    sp = spotipy.Spotify(auth=token)
    try:
        features = sp.audio_features([track_id])
        return features[0]
    except:
        return None

# %%
dmcb_features = get_features(dmcb_id, token)
print(dmcb_features)
# Out:
# {'danceability': 0.423, 'energy': 0.587, 'key': 6, 'loudness': -6.635, 'mode': 1, 'speechiness': 0.529, 'acousticness': 0.765, 'instrumentalness': 0, 'liveness': 0.114, 'valence': 0.33, 'tempo': 180.331, 'type': 'audio_features', 'id': '1qyFlfPREPbRcS2BNszdYI', 'uri': 'spotify:track:1qyFlfPREPbRcS2BNszdYI', 'track_href': 'https://api.spotify.com/v1/tracks/1qyFlfPREPbRcS2BNszdYI', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1qyFlfPREPbRcS2BNszdYI', 'duration_ms': 253803, 'time_signature': 4}

# %% [markdown]
# ## Getting playlist of Record of the Year Winners from my Spotify Library

# %%
def getTrackIDs(user, playlist_id):
    ids = []
    playlist = sp.user_playlist(user, playlist_id)
    for item in playlist['tracks']['items']:
        track = item['track']
        ids.append(track['id'])
    return ids

winner_ids = getTrackIDs('12138672436', '2BpxU8U7SC702hu66lWIUz')

# %%
print(len(winner_ids))
# Out:
# 62

# %% [markdown]
# ## Setting up data frame outlines to pull out audio features of songs from playlists

# %%
def getTrackFeatures(id):
  meta = sp.track(id)
  features = sp.audio_features(id)

  # meta
  name = meta['name']
  album = meta['album']['name']
  artist = meta['album']['artists'][0]['name']
  release_date = meta['album']['release_date']
  length = meta['duration_ms']
  popularity = meta['popularity']

  # features
  acousticness = features[0]['acousticness']
  danceability = features[0]['danceability']
  energy = features[0]['energy']
  instrumentalness = features[0]['instrumentalness']
  liveness = features[0]['liveness']
  loudness = features[0]['loudness']
  speechiness = features[0]['speechiness']
  tempo = features[0]['tempo']
  time_signature = features[0]['time_signature']

  track = [name, album, artist, release_date, length, popularity, danceability, acousticness, danceability, energy, instrumentalness, liveness, loudness, speechiness, tempo, time_signature]
  return track

# %% [markdown]
# ## Putting songs from Record of the Year Winners into a Data Frame

# %%
# loop over track ids 
tracks = []
for i in range(len(winner_ids)):
  track = getTrackFeatures(winner_ids[i])
  tracks.append(track)

# create dataset
df_winners = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'release_date', 'length', 'popularity', 'danceability', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'time_signature'])

# %%
df_winners
# Out:
#                                                 name  \
# 0                             Nel Blu Dipinto Di Blu
# 1                                     Mack the Knife
# 2   The Theme from "A Summer Place" - Single Version
# 3                                         Moon River
# 4                 (I Left My Heart) In San Francisco
# ..                                               ...
# 57                    Uptown Funk (feat. Bruno Mars)
# 58                                             Hello
# 59                                         24K Magic
# 60                                   This Is America
# 61                                           bad guy
#
#                                        album                       artist  \
# 0                     Nel Blu Dipinto Di Blu             Domenico Modugno
# 1                                 That's All                  Bobby Darin
# 2                Percy Faith'S Greatest Hits  Percy Faith & His Orchestra
# 3                The Essential Henry Mancini                Henry Mancini
# 4           I Left My Heart In San Francisco                 Tony Bennett
# ..                                       ...                          ...
# 57                            Uptown Special                  Mark Ronson
# 58                                        25                        Adele
# 59                                 24K Magic                   Bruno Mars
# 60                           This Is America             Childish Gambino
# 61  WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?                Billie Eilish
#
#    release_date  length  popularity  danceability  acousticness  danceability  \
# 0    2008-04-28  219120          56         0.547       0.98200         0.547
# 1          1959  184333          62         0.549       0.76000         0.549
# 2          1953  144893          49         0.466       0.63100         0.466
# 3          1958  160693          39         0.235       0.96600         0.235
# 4    1962-06-18  170960          62         0.313       0.95500         0.313
# ..          ...     ...         ...           ...           ...           ...
# 57   2015-01-12  269666          81         0.856       0.00801         0.856
# 58   2016-06-24  295493          72         0.481       0.33600         0.481
# 59   2016-11-17  225983          77         0.818       0.03400         0.818
# 60   2018-05-06  225773          75         0.854       0.11700         0.854
# 61   2019-03-29  194087          88         0.701       0.32800         0.701
#
#     energy  instrumentalness  liveness  loudness  speechiness    tempo  \
# 0   0.0588          0.000016    0.1930   -17.062       0.0405  129.510
# 1   0.5290          0.000000    0.2060   -12.291       0.1080   82.755
# 2   0.3890          0.843000    0.2950   -12.825       0.0253   92.631
# 3   0.2640          0.074700    0.1280   -12.817       0.0312   91.656
# 4   0.0780          0.000004    0.1690   -17.583       0.0332  128.065
# ..     ...               ...       ...       ...          ...      ...
# 57  0.6090          0.000082    0.0344    -7.223       0.0824  114.988
# 58  0.4510          0.000000    0.0872    -6.095       0.0347  157.966
# 59  0.8030          0.000000    0.1530    -4.282       0.0797  106.970
# 60  0.4630          0.000000    0.3540    -6.159       0.1370  120.024
# 61  0.4250          0.130000    0.1000   -10.965       0.3750  135.128
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                3
# 4                4
# ..             ...
# 57               4
# 58               4
# 59               4
# 60               4
# 61               4
#
# [62 rows x 16 columns]

# %% [markdown]
# Now getting playlists of non-winners (this playlist has 1995-2020 nominees)

# %%
def show_tracks(results, uriArray):
    for i, item in enumerate(results['items']):
        track = item['track']
        uriArray.append(track['id'])
        
def getTrackIDs(username, playlist_id):
    trackID = []
    results = sp.user_playlist(username, playlist_id)
    tracks = results['tracks']
    show_tracks(tracks, trackID)
    while tracks['next']:
        tracks = sp.next(tracks)
        show_tracks(tracks, trackID)
        
    return trackID

# DataFrame = getTrackIDS('username', 'playlistURI')
nw_ids = getTrackIDs('Paul Gasca', '7i0HGpe6q17NS4ek2Vtg30')

# %%
print(len(nw_ids))
# Out:
# 478

# %%
# loop over track ids 
tracks = []
for i in range(len(nw_ids)):
  track = getTrackFeatures(nw_ids[i])
  tracks.append(track)

# create dataset
df_others1 = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'release_date', 'length', 'popularity', 'danceability', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'time_signature'])

# %%
df_others1.shape
# Out:
# (478, 16)

# %%
df_others1.head()
# Out:
#                        name                                         album  \
# 0     I'll Make Love To You                                            II
# 1  He Thinks He'll Keep Her                               Come On Come On
# 2            All I Wanna Do                      Tuesday Night Music Club
# 3   Love Sneakin' Up On You                       Longing In Their Hearts
# 4   Streets of Philadelphia  PHILADELPHIA - Music From The Motion Picture
#
#                   artist release_date  length  popularity  danceability  \
# 0            Boyz II Men   1994-01-01  236773          63         0.567
# 1  Mary Chapin Carpenter   1992-06-20  241800          31         0.599
# 2            Sheryl Crow   1993-08-03  272106           0         0.820
# 3           Bonnie Raitt   1994-01-01  221626          26         0.641
# 4        Various Artists   1993-01-04  252493          37         0.708
#
#    acousticness  danceability  energy  instrumentalness  liveness  loudness  \
# 0        0.0995         0.567   0.501          0.000000    0.0986    -8.038
# 1        0.6030         0.599   0.741          0.000003    0.1220    -5.859
# 2        0.1110         0.820   0.528          0.018600    0.2570   -11.179
# 3        0.0171         0.641   0.630          0.000003    0.0559   -10.321
# 4        0.1940         0.708   0.190          0.226000    0.0916   -16.578
#
#    speechiness    tempo  time_signature
# 0       0.0241  142.589               3
# 1       0.0289  145.580               4
# 2       0.0321  120.091               4
# 3       0.0297   94.654               4
# 4       0.0326   93.669               4

# %% [markdown]
# Now getting playlists of non-winners (this playlist has 1970-1979 nominees)

# %%
# DataFrame = getTrackIDS('username', 'playlistURI')
nw_ids2 = getTrackIDs('Ludger Mayer', '7bemaSI1eSlbg78w1O8eKO')

# %%
print(len(nw_ids2))
# Out:
# 35

# %%
# loop over track ids 
tracks = []
for i in range(len(nw_ids2)):
  track = getTrackFeatures(nw_ids2[i])
  tracks.append(track)

# create dataset
df_others2 = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'release_date', 'length', 'popularity', 'danceability', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'time_signature'])

# %%
df_others2.head()
# Out:
#                                                 name  \
# 0  Aquarius/Let The Sunshine In (The Flesh Failur...
# 1                                  Games People Play
# 2                              Is That All There Is?
# 3       Everybody's Talkin' - From "Midnight Cowboy"
# 4                            Share Your Love with Me
#
#                               album             artist release_date  length  \
# 0               The Age Of Aquarius  The 5th Dimension         1969  289293
# 1  Introspect (Bonus Track Version)          Joe South   1968-01-01  215160
# 2             Is That All There Is?          Peggy Lee   1969-01-01  262000
# 3                     Aerial Ballet      Harry Nilsson   1968-07-01  163586
# 4      This Girl's in Love with You    Aretha Franklin   1970-01-15  201906
#
#    popularity  danceability  acousticness  danceability  energy  \
# 0          58         0.293         0.446         0.293  0.7400
# 1          45         0.334         0.251         0.334  0.7140
# 2          51         0.458         0.863         0.458  0.0899
# 3          67         0.438         0.338         0.438  0.3490
# 4          37         0.435         0.528         0.435  0.3110
#
#    instrumentalness  liveness  loudness  speechiness    tempo  time_signature
# 0          0.001510    0.0998    -6.098       0.0399  118.230               4
# 1          0.000043    0.2570    -8.379       0.1550  172.288               4
# 2          0.000000    0.1370   -18.824       0.0362  109.574               4
# 3          0.000057    0.4170   -15.569       0.0380  124.984               4
# 4          0.000056    0.1160   -12.342       0.0331  121.414               3

# %% [markdown]
# Now getting playlists of non-winners (Another playlist of nominees for song & record of the year)

# %%
# DataFrame = getTrackIDS('username', 'playlistURI')
nw_ids3 = getTrackIDs('jeremyheilman', '28eVcsXZ43LT7LGMQBdMHF')

# %%
print(len(nw_ids3))
# Out:
# 455

# %%
# loop over track ids 
tracks = []
for i in range(len(nw_ids3)):
  track = getTrackFeatures(nw_ids3[i])
  tracks.append(track)

# create dataset
df_others3 = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'release_date', 'length', 'popularity', 'danceability', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'time_signature'])

# %%
df_others3.head()
# Out:
#                           name                                         album  \
# 0                      bad guy      WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?
# 1  Always Remember Us This Way  A Star Is Born Soundtrack (Without Dialogue)
# 2         Bring My Flowers Now                              While I'm Livin'
# 3                   Hard Place                                    Hard Place
# 4                        Lover                                         Lover
#
#           artist release_date  length  popularity  danceability  acousticness  \
# 0  Billie Eilish   2019-03-29  194087          88         0.701         0.328
# 1      Lady Gaga   2018-10-05  210200          78         0.553         0.299
# 2   Tanya Tucker   2019-08-23  260360          44         0.557         0.948
# 3         H.E.R.   2018-11-02  271733          65         0.614         0.179
# 4   Taylor Swift   2019-08-23  221306          79         0.359         0.492
#
#    danceability  energy  instrumentalness  liveness  loudness  speechiness  \
# 0         0.701   0.425          0.130000     0.100   -10.965       0.3750
# 1         0.553   0.502          0.000000     0.764    -5.972       0.0409
# 2         0.557   0.198          0.000009     0.217    -9.911       0.0461
# 3         0.614   0.719          0.000017     0.163    -4.694       0.0955
# 4         0.359   0.543          0.000016     0.118    -7.582       0.0919
#
#      tempo  time_signature
# 0  135.128               4
# 1  129.976               4
# 2  133.823               4
# 3  160.075               4
# 4   68.534               4

# %%
df_others3.shape
# Out:
# (455, 16)

# %% [markdown]
# Another playlist 2015-2020

# %%
nw_ids4 = getTrackIDs('Rasmus Tobiasen', '3tIEIgEUkSbFiPasg8ziem')

# %%
# loop over track ids 
tracks = []
for i in range(len(nw_ids4)):
  track = getTrackFeatures(nw_ids4[i])
  tracks.append(track)

# create dataset
df_others4 = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'release_date', 'length', 'popularity', 'danceability', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'time_signature'])

# %%
df_others4.head()
# Out:
#                     name                                album      artist  \
# 0             Like I Can  In The Lonely Hour (Deluxe Edition)   Sam Smith
# 1              Firestone                            Firestone        Kygo
# 2      Thinking out Loud                   x (Deluxe Edition)  Ed Sheeran
# 3  Samsara (feat. Emila)                Samsara (feat. Emila)   Tungevaag
# 4                  Sugar                           V (Deluxe)    Maroon 5
#
#   release_date  length  popularity  danceability  acousticness  danceability  \
# 0   2014-01-01  167065           0         0.654       0.35600         0.654
# 1   2015-06-24  273684          20         0.486       0.40800         0.486
# 2   2014-06-21  281560          83         0.781       0.47400         0.781
# 3   2015-01-21  211884          62         0.489       0.00598         0.489
# 4   2014-09-02  235493           0         0.744       0.05530         0.744
#
#    energy  instrumentalness  liveness  loudness  speechiness    tempo  \
# 0   0.631          0.000026     0.124    -6.611       0.0395   99.940
# 1   0.652          0.000066     0.077    -7.226       0.0520  113.055
# 2   0.445          0.000000     0.184    -6.061       0.0295   78.998
# 3   0.641          0.020100     0.122    -7.011       0.0320  108.901
# 4   0.783          0.000000     0.086    -7.077       0.0337  120.042
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
df_others4.shape
# Out:
# (1863, 16)

# %% [markdown]
# Another playlist 1980s

# %%
nw_ids5 = getTrackIDs('Diane Elizabeth Jansen Riber', '2uzORc0dpwNs8LdQ2IwFCa')

# %%
# loop over track ids 
tracks = []
for i in range(len(nw_ids5)):
  track = getTrackFeatures(nw_ids5[i])
  tracks.append(track)

# create dataset
df_others5 = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'release_date', 'length', 'popularity', 'danceability', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'time_signature'])

# %%
df_others5.head()
# Out:
#                       name                                              album  \
# 0                     Roam                                       Cosmic Thing
# 1             Legal Tender                                            Whammy!
# 2      Give Me Back My Man                                        Wild Planet
# 3  Really Saying Something  Really Saying Something: The Best of Fun Boy T...
# 4             Cruel Summer   The Greatest Hits Collection (Collector Edition)
#
#           artist release_date  length  popularity  danceability  acousticness  \
# 0     The B-52's   1989-06-23  295133          57         0.631        0.0447
# 1     The B-52's   1983-04-20  220666          44         0.756        0.0248
# 2     The B-52's         1980  240800          43         0.571        0.0137
# 3  Fun Boy Three   1997-02-03  165079          18         0.725        0.6170
# 4     Bananarama   2017-11-24  215400          54         0.697        0.3430
#
#    danceability  energy  instrumentalness  liveness  loudness  speechiness  \
# 0         0.631   0.938          0.000008    0.3000    -5.573       0.0833
# 1         0.756   0.675          0.001080    0.0714    -7.730       0.0478
# 2         0.571   0.960          0.008170    0.0591    -5.498       0.0354
# 3         0.725   0.939          0.000005    0.3400    -7.044       0.0548
# 4         0.697   0.828          0.015400    0.2710    -8.796       0.0266
#
#      tempo  time_signature
# 0  134.916               4
# 1  148.049               4
# 2  162.297               4
# 3  134.077               4
# 4  108.367               4

# %% [markdown]
# Another playlist 1990s

# %%
nw_ids6 = getTrackIDs('-_JT_-', '4vhyj0rJjdb2Nzzu8LJRsv')

# %%
# loop over track ids 
tracks = []
for i in range(len(nw_ids6)):
  track = getTrackFeatures(nw_ids6[i])
  tracks.append(track)

# create dataset
df_others6 = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'release_date', 'length', 'popularity', 'danceability', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'time_signature'])

# %%
df_others6.head()
# Out:
#                  name            album       artist release_date  length  \
# 0       Thunderstruck  The Razors Edge        AC/DC   1990-09-24  292880
# 1  All That She Wants         The Sign  Ace of Base   1993-12-24  211213
# 2      Beautiful Life       The Bridge  Ace of Base   1995-11-07  221186
# 3   Don't Turn Around         The Sign  Ace of Base   1993-12-24  230186
# 4            The Sign         The Sign  Ace of Base   1993-12-24  191240
#
#    popularity  danceability  acousticness  danceability  energy  \
# 0          82         0.502      0.000147         0.502   0.890
# 1          72         0.798      0.005470         0.798   0.625
# 2          63         0.749      0.202000         0.749   0.988
# 3          56         0.745      0.001040         0.745   0.771
# 4          69         0.808      0.009280         0.808   0.786
#
#    instrumentalness  liveness  loudness  speechiness    tempo  time_signature
# 0           0.01170    0.2170    -5.175       0.0364  133.520               4
# 1           0.00008    0.1030    -9.689       0.0548   93.764               4
# 2           0.00631    0.1700    -5.266       0.0387  135.015               4
# 3           0.38700    0.0574    -8.231       0.0755   95.623               4
# 4           0.07010    0.0574    -6.897       0.0447   96.987               4

# %% [markdown]
# Last Playlist (4K songs)

# %%
nw_ids7 = getTrackIDs('Susanna Ketola', '4rnleEAOdmFAbRcNCgZMpY')

# %%
# loop over track ids 
tracks = []
for i in range(len(nw_ids7)):
  track = getTrackFeatures(nw_ids7[i])
  tracks.append(track)

# create dataset
df_others7 = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'release_date', 'length', 'popularity', 'danceability', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'time_signature'])

# %%
df_others7.head()
# Out:
#                                  name  \
# 0                   Take Me To Church
# 1         Cooler Than Me - Single Mix
# 2    See You Again (feat. Kali Uchis)
# 3                             Pompeii
# 4  Hips Don't Lie (feat. Wyclef Jean)
#
#                                       album              artist release_date  \
# 0                           Hozier (Deluxe)              Hozier   2014-05-20
# 1                     31 Minutes to Takeoff         Mike Posner   2010-08-09
# 2                                Flower Boy  Tyler, The Creator   2017-07-21
# 3                                 Bad Blood            Bastille   2013-01-01
# 4  Oral Fixation, Vol. 2 (Expanded Edition)             Shakira   2005-11-28
#
#    length  popularity  danceability  acousticness  danceability  energy  \
# 0  241688           0         0.566        0.6340         0.566   0.664
# 1  213293          72         0.768        0.1790         0.768   0.820
# 2  180386          79         0.558        0.3710         0.558   0.559
# 3  214147          71         0.679        0.0755         0.679   0.715
# 4  218093          83         0.778        0.2840         0.778   0.824
#
#    instrumentalness  liveness  loudness  speechiness    tempo  time_signature
# 0          0.000000     0.116    -5.303       0.0464  128.945               4
# 1          0.000000     0.704    -4.630       0.0475  129.969               4
# 2          0.000007     0.109    -9.222       0.0959   78.558               4
# 3          0.000000     0.271    -6.383       0.0407  127.435               4
# 4          0.000000     0.405    -5.892       0.0712  100.024               4

# %% [markdown]
# Now going to merge all of the dataframes BESIDES the winners one

# %%
frames = [df_others1, df_others2, df_others3, df_others4, df_others5, df_others6, df_others7]

df_all_others = pd.concat(frames)

# %%
df_all_others.shape
# Out:
# (8396, 16)

# %%
# Check info of this data frame

df_all_others.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8396 entries, 0 to 4777
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              8396 non-null   object
#  1   album             8396 non-null   object
#  2   artist            8396 non-null   object
#  3   release_date      8396 non-null   object
#  4   length            8396 non-null   int64
#  5   popularity        8396 non-null   int64
#  6   danceability      8396 non-null   float64
#  7   acousticness      8396 non-null   float64
#  8   danceability      8396 non-null   float64
#  9   energy            8396 non-null   float64
#  10  instrumentalness  8396 non-null   float64
#  11  liveness          8396 non-null   float64
#  12  loudness          8396 non-null   float64
#  13  speechiness       8396 non-null   float64
#  14  tempo             8396 non-null   float64
#  15  time_signature    8396 non-null   int64
# dtypes: float64(9), int64(3), object(4)
# memory usage: 1.1+ MB

# %%
# dropping any duplicated rows

df_all_others.drop_duplicates()
# Out:
#                                    name  \
# 0                 I'll Make Love To You
# 1              He Thinks He'll Keep Her
# 2                        All I Wanna Do
# 3               Love Sneakin' Up On You
# 4               Streets of Philadelphia
# ...                                 ...
# 4773               Devil In A New Dress
# 4774                             Nights
# 4775  Pound Cake / Paris Morton Music 2
# 4776                     Scared Of Love
# 4777                       I'll Be Fine
#
#                                              album                 artist  \
# 0                                               II            Boyz II Men
# 1                                  Come On Come On  Mary Chapin Carpenter
# 2                         Tuesday Night Music Club            Sheryl Crow
# 3                          Longing In Their Hearts           Bonnie Raitt
# 4     PHILADELPHIA - Music From The Motion Picture        Various Artists
# ...                                            ...                    ...
# 4773             My Beautiful Dark Twisted Fantasy             Kanye West
# 4774                                        Blonde            Frank Ocean
# 4775                 Nothing Was The Same (Deluxe)                  Drake
# 4776                       Goodbye & Good Riddance             Juice WRLD
# 4777                       Goodbye & Good Riddance             Juice WRLD
#
#      release_date  length  popularity  danceability  acousticness  \
# 0      1994-01-01  236773          63         0.567      0.099500
# 1      1992-06-20  241800          31         0.599      0.603000
# 2      1993-08-03  272106           0         0.820      0.111000
# 3      1994-01-01  221626          26         0.641      0.017100
# 4      1993-01-04  252493          37         0.708      0.194000
# ...           ...     ...         ...           ...           ...
# 4773   2010-11-22  351946          69         0.435      0.017500
# 4774   2016-08-20  307151          78         0.466      0.420000
# 4775   2013-01-01  433800          65         0.521      0.138000
# 4776   2018-12-10  170538          74         0.642      0.032000
# 4777   2018-12-10  244193          74         0.523      0.000616
#
#       danceability  energy  instrumentalness  liveness  loudness  speechiness  \
# 0            0.567   0.501          0.000000    0.0986    -8.038       0.0241
# 1            0.599   0.741          0.000003    0.1220    -5.859       0.0289
# 2            0.820   0.528          0.018600    0.2570   -11.179       0.0321
# 3            0.641   0.630          0.000003    0.0559   -10.321       0.0297
# 4            0.708   0.190          0.226000    0.0916   -16.578       0.0326
# ...            ...     ...               ...       ...       ...          ...
# 4773         0.435   0.760          0.000000    0.1580    -4.935       0.0721
# 4774         0.466   0.548          0.000001    0.1130    -9.362       0.1180
# 4775         0.521   0.762          0.000011    0.1140    -6.746       0.5290
# 4776         0.642   0.562          0.000000    0.1680    -4.869       0.0812
# 4777         0.523   0.678          0.000000    0.1420    -6.071       0.0692
#
#         tempo  time_signature
# 0     142.589               3
# 1     145.580               4
# 2     120.091               4
# 3      94.654               4
# 4      93.669               4
# ...       ...             ...
# 4773   80.082               4
# 4774   89.815               4
# 4775  164.090               4
# 4776  158.001               4
# 4777  159.909               4
#
# [7878 rows x 16 columns]

# %% [markdown]
# Going to get more songs to help get this dataframe over 8,000 rows

# %%
nw_ids8 = getTrackIDs('Russ Laney', '5WAM4qc14blQMfJtyvh3Yq')

# %%
# loop over track ids 
tracks = []
for i in range(len(nw_ids8)):
  track = getTrackFeatures(nw_ids8[i])
  tracks.append(track)

# create dataset
df_others8 = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'release_date', 'length', 'popularity', 'danceability', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'time_signature'])

# %%
# Concattenating the data frames

frames = [df_others1, df_others2, df_others3, df_others4, df_others5, df_others6, df_others7, df_others8]

df_all_others = pd.concat(frames)

# %%
df_all_others.shape
# Out:
# (8995, 16)

# %%
df_all_others.drop_duplicates()
# Out:
#                                                   name  \
# 0                                I'll Make Love To You
# 1                             He Thinks He'll Keep Her
# 2                                       All I Wanna Do
# 3                              Love Sneakin' Up On You
# 4                              Streets of Philadelphia
# ..                                                 ...
# 594                                       Goodbye Girl
# 595                                    My Cherie Amour
# 596  How Deep Is Your Love (2007 Remastered Saturda...
# 597                                       Get Together
# 598                                      Brand New Key
#
#                                                  album                 artist  \
# 0                                                   II            Boyz II Men
# 1                                      Come On Come On  Mary Chapin Carpenter
# 2                             Tuesday Night Music Club            Sheryl Crow
# 3                              Longing In Their Hearts           Bonnie Raitt
# 4         PHILADELPHIA - Music From The Motion Picture        Various Artists
# ..                                                 ...                    ...
# 594                                       Goodbye Girl            David Gates
# 595                                    My Cherie Amour          Stevie Wonder
# 596  Saturday Night Fever [The Original Movie Sound...               Bee Gees
# 597            Get Together: The Essential Youngbloods        The Youngbloods
# 598     Beautiful People: The Greatest Hits of Melanie                Melanie
#
#     release_date  length  popularity  danceability  acousticness  \
# 0     1994-01-01  236773          63         0.567        0.0995
# 1     1992-06-20  241800          31         0.599        0.6030
# 2     1993-08-03  272106           0         0.820        0.1110
# 3     1994-01-01  221626          26         0.641        0.0171
# 4     1993-01-04  252493          37         0.708        0.1940
# ..           ...     ...         ...           ...           ...
# 594         1978  168866          60         0.467        0.6050
# 595   1969-08-01  173306           0         0.570        0.2820
# 596   1978-01-05  245200           0         0.630        0.0999
# 597   2002-05-06  276466          44         0.533        0.3510
# 598   1999-07-01  144866          52         0.667        0.8170
#
#      danceability  energy  instrumentalness  liveness  loudness  speechiness  \
# 0           0.567   0.501          0.000000    0.0986    -8.038       0.0241
# 1           0.599   0.741          0.000003    0.1220    -5.859       0.0289
# 2           0.820   0.528          0.018600    0.2570   -11.179       0.0321
# 3           0.641   0.630          0.000003    0.0559   -10.321       0.0297
# 4           0.708   0.190          0.226000    0.0916   -16.578       0.0326
# ..            ...     ...               ...       ...       ...          ...
# 594         0.467   0.255          0.000310    0.2730   -15.963       0.0372
# 595         0.570   0.523          0.000003    0.2480   -11.052       0.0277
# 596         0.630   0.357          0.000000    0.1280    -9.392       0.0260
# 597         0.533   0.580          0.002780    0.0865    -9.265       0.0256
# 598         0.667   0.412          0.000000    0.1070    -7.544       0.0353
#
#        tempo  time_signature
# 0    142.589               3
# 1    145.580               4
# 2    120.091               4
# 3     94.654               4
# 4     93.669               4
# ..       ...             ...
# 594  120.174               4
# 595  101.137               4
# 596  104.965               4
# 597  103.127               4
# 598   83.816               4
#
# [8432 rows x 16 columns]

# %%
df_non_winners = df_all_others.drop_duplicates()

# %%
df_non_winners.shape
# Out:
# (8432, 16)

# %%
df_non_winners.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8432 entries, 0 to 598
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              8432 non-null   object
#  1   album             8432 non-null   object
#  2   artist            8432 non-null   object
#  3   release_date      8432 non-null   object
#  4   length            8432 non-null   int64
#  5   popularity        8432 non-null   int64
#  6   danceability      8432 non-null   float64
#  7   acousticness      8432 non-null   float64
#  8   danceability      8432 non-null   float64
#  9   energy            8432 non-null   float64
#  10  instrumentalness  8432 non-null   float64
#  11  liveness          8432 non-null   float64
#  12  loudness          8432 non-null   float64
#  13  speechiness       8432 non-null   float64
#  14  tempo             8432 non-null   float64
#  15  time_signature    8432 non-null   int64
# dtypes: float64(9), int64(3), object(4)
# memory usage: 1.1+ MB

# %% [markdown]
# ## Merging the Winners with the Non-Winners data frame

# %%
frames2 = [df_winners, df_non_winners]

df_all = pd.concat(frames2)

# %%
df_all.head()
# Out:
#                                                name  \
# 0                            Nel Blu Dipinto Di Blu
# 1                                    Mack the Knife
# 2  The Theme from "A Summer Place" - Single Version
# 3                                        Moon River
# 4                (I Left My Heart) In San Francisco
#
#                               album                       artist release_date  \
# 0            Nel Blu Dipinto Di Blu             Domenico Modugno   2008-04-28
# 1                        That's All                  Bobby Darin         1959
# 2       Percy Faith'S Greatest Hits  Percy Faith & His Orchestra         1953
# 3       The Essential Henry Mancini                Henry Mancini         1958
# 4  I Left My Heart In San Francisco                 Tony Bennett   1962-06-18
#
#    length  popularity  danceability  acousticness  danceability  energy  \
# 0  219120          56         0.547         0.982         0.547  0.0588
# 1  184333          62         0.549         0.760         0.549  0.5290
# 2  144893          49         0.466         0.631         0.466  0.3890
# 3  160693          39         0.235         0.966         0.235  0.2640
# 4  170960          62         0.313         0.955         0.313  0.0780
#
#    instrumentalness  liveness  loudness  speechiness    tempo  time_signature
# 0          0.000016     0.193   -17.062       0.0405  129.510               4
# 1          0.000000     0.206   -12.291       0.1080   82.755               4
# 2          0.843000     0.295   -12.825       0.0253   92.631               4
# 3          0.074700     0.128   -12.817       0.0312   91.656               3
# 4          0.000004     0.169   -17.583       0.0332  128.065               4

# %%
df_all.shape
# Out:
# (8494, 16)

# %%
# Dropping any duplicates to create the final data frame

df_master = df_all.drop_duplicates()

# %%
df_master.shape
# Out:
# (8439, 16)

# %%
# Adding a new column to show Record of the Year winners
# All tracks in index 0 - 61 are winners

df_master['record_of_the_year'] = 1
# Out:
# <ipython-input-146-768302ef197b>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_master['record_of_the_year'] = 1

# %%
df_master.head(63)
# Out:
#                                                 name  \
# 0                             Nel Blu Dipinto Di Blu
# 1                                     Mack the Knife
# 2   The Theme from "A Summer Place" - Single Version
# 3                                         Moon River
# 4                 (I Left My Heart) In San Francisco
# ..                                               ...
# 58                                             Hello
# 59                                         24K Magic
# 60                                   This Is America
# 61                                           bad guy
# 0                              I'll Make Love To You
#
#                                        album                       artist  \
# 0                     Nel Blu Dipinto Di Blu             Domenico Modugno
# 1                                 That's All                  Bobby Darin
# 2                Percy Faith'S Greatest Hits  Percy Faith & His Orchestra
# 3                The Essential Henry Mancini                Henry Mancini
# 4           I Left My Heart In San Francisco                 Tony Bennett
# ..                                       ...                          ...
# 58                                        25                        Adele
# 59                                 24K Magic                   Bruno Mars
# 60                           This Is America             Childish Gambino
# 61  WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?                Billie Eilish
# 0                                         II                  Boyz II Men
#
#    release_date  length  popularity  danceability  acousticness  danceability  \
# 0    2008-04-28  219120          56         0.547        0.9820         0.547
# 1          1959  184333          62         0.549        0.7600         0.549
# 2          1953  144893          49         0.466        0.6310         0.466
# 3          1958  160693          39         0.235        0.9660         0.235
# 4    1962-06-18  170960          62         0.313        0.9550         0.313
# ..          ...     ...         ...           ...           ...           ...
# 58   2016-06-24  295493          72         0.481        0.3360         0.481
# 59   2016-11-17  225983          77         0.818        0.0340         0.818
# 60   2018-05-06  225773          75         0.854        0.1170         0.854
# 61   2019-03-29  194087          88         0.701        0.3280         0.701
# 0    1994-01-01  236773          63         0.567        0.0995         0.567
#
#     energy  instrumentalness  liveness  loudness  speechiness    tempo  \
# 0   0.0588          0.000016    0.1930   -17.062       0.0405  129.510
# 1   0.5290          0.000000    0.2060   -12.291       0.1080   82.755
# 2   0.3890          0.843000    0.2950   -12.825       0.0253   92.631
# 3   0.2640          0.074700    0.1280   -12.817       0.0312   91.656
# 4   0.0780          0.000004    0.1690   -17.583       0.0332  128.065
# ..     ...               ...       ...       ...          ...      ...
# 58  0.4510          0.000000    0.0872    -6.095       0.0347  157.966
# 59  0.8030          0.000000    0.1530    -4.282       0.0797  106.970
# 60  0.4630          0.000000    0.3540    -6.159       0.1370  120.024
# 61  0.4250          0.130000    0.1000   -10.965       0.3750  135.128
# 0   0.5010          0.000000    0.0986    -8.038       0.0241  142.589
#
#     time_signature  record_of_the_year
# 0                4                   1
# 1                4                   1
# 2                4                   1
# 3                3                   1
# 4                4                   1
# ..             ...                 ...
# 58               4                   1
# 59               4                   1
# 60               4                   1
# 61               4                   1
# 0                3                   1
#
# [63 rows x 17 columns]

# %%
df_master.iloc[62:8439, :]['record_of_the_year'] = 0
# Out:
# <ipython-input-154-f6ec7c27d9ae>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_master.iloc[62:8439, :]['record_of_the_year'] = 0

# %%
df_master
# Out:
#                                                   name  \
# 0                               Nel Blu Dipinto Di Blu
# 1                                       Mack the Knife
# 2     The Theme from "A Summer Place" - Single Version
# 3                                           Moon River
# 4                   (I Left My Heart) In San Francisco
# ..                                                 ...
# 594                                       Goodbye Girl
# 595                                    My Cherie Amour
# 596  How Deep Is Your Love (2007 Remastered Saturda...
# 597                                       Get Together
# 598                                      Brand New Key
#
#                                                  album  \
# 0                               Nel Blu Dipinto Di Blu
# 1                                           That's All
# 2                          Percy Faith'S Greatest Hits
# 3                          The Essential Henry Mancini
# 4                     I Left My Heart In San Francisco
# ..                                                 ...
# 594                                       Goodbye Girl
# 595                                    My Cherie Amour
# 596  Saturday Night Fever [The Original Movie Sound...
# 597            Get Together: The Essential Youngbloods
# 598     Beautiful People: The Greatest Hits of Melanie
#
#                           artist release_date  length  popularity  \
# 0               Domenico Modugno   2008-04-28  219120          56
# 1                    Bobby Darin         1959  184333          62
# 2    Percy Faith & His Orchestra         1953  144893          49
# 3                  Henry Mancini         1958  160693          39
# 4                   Tony Bennett   1962-06-18  170960          62
# ..                           ...          ...     ...         ...
# 594                  David Gates         1978  168866          60
# 595                Stevie Wonder   1969-08-01  173306           0
# 596                     Bee Gees   1978-01-05  245200           0
# 597              The Youngbloods   2002-05-06  276466          44
# 598                      Melanie   1999-07-01  144866          52
#
#      danceability  acousticness  danceability  energy  instrumentalness  \
# 0           0.547        0.9820         0.547  0.0588          0.000016
# 1           0.549        0.7600         0.549  0.5290          0.000000
# 2           0.466        0.6310         0.466  0.3890          0.843000
# 3           0.235        0.9660         0.235  0.2640          0.074700
# 4           0.313        0.9550         0.313  0.0780          0.000004
# ..            ...           ...           ...     ...               ...
# 594         0.467        0.6050         0.467  0.2550          0.000310
# 595         0.570        0.2820         0.570  0.5230          0.000003
# 596         0.630        0.0999         0.630  0.3570          0.000000
# 597         0.533        0.3510         0.533  0.5800          0.002780
# 598         0.667        0.8170         0.667  0.4120          0.000000
#
#      liveness  loudness  speechiness    tempo  time_signature  \
# 0      0.1930   -17.062       0.0405  129.510               4
# 1      0.2060   -12.291       0.1080   82.755               4
# 2      0.2950   -12.825       0.0253   92.631               4
# 3      0.1280   -12.817       0.0312   91.656               3
# 4      0.1690   -17.583       0.0332  128.065               4
# ..        ...       ...          ...      ...             ...
# 594    0.2730   -15.963       0.0372  120.174               4
# 595    0.2480   -11.052       0.0277  101.137               4
# 596    0.1280    -9.392       0.0260  104.965               4
# 597    0.0865    -9.265       0.0256  103.127               4
# 598    0.1070    -7.544       0.0353   83.816               4
#
#      record_of_the_year
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1
# ..                  ...
# 594                   0
# 595                   0
# 596                   0
# 597                   0
# 598                   0
#
# [8439 rows x 17 columns]

# %% [markdown]
# ## Saving the data frame to a .csv

# %%
df_master.to_csv('Record_of_the_Year.csv')
